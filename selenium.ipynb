# %%
# !pip install selenium

# %%
# !pip install pyautogui
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.53-py3-none-any.whl size=36613 sha256=88438da44c2a1f1f1d1f0a3b907ba45a8ac1c61a56c2b25936ddc48df4d4763f
#   Stored in directory: c:\users\changuk\appdata\local\pip\cache\wheels\d8\97\e4\d2edca92a87d3b5fbfb527264750a17b4ba297b9a7cab6e67f
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
import pyautogui


stations1 = ['021015', '021018', '021030', '021037', '950402', '940075', '950382', '950383', '960668',
'960669']

stations2 = ['950452', '950454', '960672', '960693', '960700', '960706', '960658']

driver = webdriver.Chrome()
url = 'https://terras.gsi.go.jp/data_service.php#5/34.957995/138.713379/&base=pale&ls=pale%7Ckijuntengis_works%7Ckijuntengis_plan%7Ckijuntengis_stop&disp=1111&vs=c1j0h0k0l0u0t0z0r0s0f1'
driver.get(url)
driver.find_element_by_class_name('fright').click()

# ID / PW 입력
driver.find_element_by_id('user').send_keys("dnr8874")
driver.find_element_by_id('passwd').send_keys("|k9LjM.6m")
driver.find_element_by_id('btn_login').click()

# 동의함 버튼 클릭
driver.implicitly_wait(10)
driver.find_element_by_xpath("/html/body/div[2]/center/table/tbody/tr/td/input[1]").click()

driver.implicitly_wait(3)
driver.find_element_by_id('btn_mnu_search').click()
driver.find_element_by_class_name('search_id').send_keys("021015")


driver.find_element_by_id('btn_search').click()
driver.find_element_by_xpath("/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/tbody/tr/td/div/table/tbody/tr/td[1]/input").click()

driver.find_element_by_xpath("/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/tbody/tr/td/center/img").click()

driver.find_element_by_id('btn_mnu_search').click()
driver.find_element_by_class_name('search_id').send_keys("021018")

driver.implicitly_wait(2)
driver.find_element_by_id('btn_search').click()
driver.find_element_by_xpath("/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/thead/tr/th[1]/input").click()

driver.find_element_by_xpath("/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/tbody/tr/td/center/img").click()

for i in range(len(stations1) - 2):
  driver.find_element_by_id('btn_mnu_search').click()
  driver.find_element_by_class_name('search_id').send_keys(stations1[i+2])
  driver.find_element_by_id('btn_search').click()
  driver.find_element_by_xpath('/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/thead/tr/th[1]/input').click()
  driver.find_element_by_xpath('/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/thead/tr/th[1]/input').click()

  driver.find_element_by_xpath("/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/tbody/tr/td/center/img").click()

driver.find_element_by_xpath("/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[1]/form[1]/table/tbody/tr/td/div/table/tbody/tr/td/center/img[4]").click()

driver.implicitly_wait(2)


# # Start Year 2012
# pyautogui.moveTo(215, 873, 0.5)
# pyautogui.click()
# pyautogui.moveTo(215, 813, 0.5)
# pyautogui.click()

# # Start Month Jan
# pyautogui.moveTo(269, 873, 0.5)
# pyautogui.click()
# pyautogui.moveTo(269, 668, 0.5)
# pyautogui.click()

# # Start Day 1
# pyautogui.moveTo(333, 873, 0.5)
# pyautogui.click()
# pyautogui.moveTo(333, 535, 0.5)
# pyautogui.click()

# # End Year 2012
# pyautogui.moveTo(215, 892, 0.5)
# pyautogui.click()
# pyautogui.moveTo(215, 832, 0.5)
# pyautogui.click()


# # End Month Jan
# pyautogui.moveTo(269, 892, 0.5)
# pyautogui.click()
# pyautogui.moveTo(269, 687, 0.5)
# pyautogui.click()


# # End Day 11
# pyautogui.moveTo(333, 892, 0.5)
# pyautogui.click()
# pyautogui.moveTo(333, 723, 0.5)
# pyautogui.click()

# # GPS and GLONASS
# # pyautogui.moveTo(202, 913, 0.5)
# # pyautogui.click()
# # pyautogui.moveTo(202, 949, 0.5)
# # pyautogui.click()

# # Downloads
# pyautogui.moveTo(456, 976, 0.5)
# pyautogui.click()

# pyautogui.moveTo(801, 308, 2)
# pyautogui.click()

# pyautogui.moveTo(590, 180, 0.5)
# pyautogui.click()

# pyautogui.moveTo(766, 280, 10)
# pyautogui.click()
# Out:
# C:\Users\changuk\AppData\Local\Temp/ipykernel_11920/3164905900.py:14: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   driver.find_element_by_class_name('fright').click()
# C:\Users\changuk\AppData\Local\Temp/ipykernel_11920/3164905900.py:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('user').send_keys("dnr8874")
# C:\Users\changuk\AppData\Local\Temp/ipykernel_11920/3164905900.py:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('passwd').send_keys("|k9LjM.6m")
# C:\Users\changuk\AppData\Local\Temp/ipykernel_11920/3164905900.py:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('btn_login').click()
# ...

# %%
years = [2012, 2016, 2020]

for year in years:
  driver.find_element_by_id('day_st_year').setAttribute("value", year)
# Out:
# C:\Users\changuk\AppData\Local\Temp/ipykernel_11920/1115905769.py:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('day_st_year').setAttribute("value", year)
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11920/1115905769.py in <module>
#       2
#       3 for year in years:
# ----> 4   driver.find_element_by_id('day_st_year').setAttribute("value", year)
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_id(self, id_)
#     471             stacklevel=2,
#     472         )
# --> 473         return self.find_element(by=By.ID, value=id_)
#     474
#     475     def find_elements_by_id(self, id_) -> List[WebElement]:
#
# ~\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
# ...

# %%
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains


stations1 = ['021015', '021018', '021030', '021037', '950402', '940075', '950382', '950383', '960668',
'960669']

stations2 = ['950452', '950454', '960672', '960693', '960700', '960706', '960658']

driver = webdriver.Chrome()
url = 'https://terras.gsi.go.jp/data_download.php'
driver.get(url)
driver.find_element_by_class_name('fright').click()

# ID / PW 입력
driver.find_element_by_id('user').send_keys("dnr8874")
driver.find_element_by_id('passwd').send_keys("|k9LjM.6m")
driver.find_element_by_id('btn_login').click()

# 동의함 버튼 클릭
driver.implicitly_wait(10)
driver.find_element_by_xpath("/html/body/div[2]/center/table/tbody/tr/td/input[1]").click()

driver.implicitly_wait(3)
driver.find_element_by_id('btn_mnu_search').click()
driver.find_element_by_class_name('search_id').send_keys("021015")


driver.find_element_by_id('btn_search').click()
driver.find_element_by_xpath("/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/tbody/tr/td/div/table/tbody/tr/td[1]/input").click()

driver.find_element_by_xpath("/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/tbody/tr/td/center/img").click()

driver.find_element_by_id('btn_mnu_search').click()
driver.find_element_by_class_name('search_id').send_keys("021018")

driver.implicitly_wait(2)
driver.find_element_by_id('btn_search').click()
driver.find_element_by_xpath("/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/thead/tr/th[1]/input").click()

driver.find_element_by_xpath("/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/tbody/tr/td/center/img").click()

for i in range(len(stations1) - 2):
  driver.find_element_by_id('btn_mnu_search').click()
  driver.find_element_by_class_name('search_id').send_keys(stations1[i+2])
  driver.find_element_by_id('btn_search').click()
  driver.find_element_by_xpath('/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/thead/tr/th[1]/input').click()
  driver.find_element_by_xpath('/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/thead/tr/th[1]/input').click()

  driver.find_element_by_xpath("/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/tbody/tr/td/center/img").click()

driver.find_element_by_xpath("/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[1]/form[1]/table/tbody/tr/td/div/table/tbody/tr/td/center/img[4]").click()


# years = [2012, 2016, 2020]

# for year in years:
#   driver.find_element_by_selector('#day_st_year').send_keys('value', year)



# # test
# driver.find_element_by_id('btn_mnu_search').click()
# driver.find_element_by_class_name('search_id').send_keys("021018")

# driver.implicitly_wait(2)
# driver.find_element_by_id('btn_search').click()
# driver.find_element_by_xpath("/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/thead/tr/th[1]/input").click()

# driver.find_element_by_xpath("/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/tbody/tr/td/center/img").click()

# # test
# driver.find_element_by_id('btn_mnu_search').click()
# driver.find_element_by_class_name('search_id').send_keys("021030")

# driver.implicitly_wait(2)

# driver.find_element_by_xpath('/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[1]/tbody/tr[6]/td/img[1]').click() 
# driver.find_element_by_xpath('/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/thead/tr/th[1]/input').click()
# driver.find_element_by_xpath('/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/thead/tr/th[1]/input').click()

# driver.find_element_by_xpath("/html/body/div[2]/div[3]/div/div/table/tbody/tr/td/div[4]/div[2]/form/table[2]/tbody/tr/td/div[2]/table/tbody/tr/td/center/img").click()
# Out:
# C:\Users\changuk\AppData\Local\Temp/ipykernel_38652/2304338447.py:13: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   driver.find_element_by_class_name('fright').click()
# C:\Users\changuk\AppData\Local\Temp/ipykernel_38652/2304338447.py:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('user').send_keys("dnr8874")
# C:\Users\changuk\AppData\Local\Temp/ipykernel_38652/2304338447.py:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('passwd').send_keys("|k9LjM.6m")
# C:\Users\changuk\AppData\Local\Temp/ipykernel_38652/2304338447.py:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_id('btn_login').click()
# ...

# %%
from selenium import webdriver
driver = webdriver.Chrome()
url = 'https://www.naver.com'
driver.get(url)


driver.find_element_by_xpath("/html/body/div[2]/div[3]/div[3]/div/div[2]/a").click()
# Out:
# C:\Users\changuk\AppData\Local\Temp/ipykernel_11920/102769551.py:7: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   driver.find_element_by_xpath("/html/body/div[2]/div[3]/div[3]/div/div[2]/a").click()

# %%
# import pyautogui
# import time

# month = 12
# start_day_px = 873


# # Start Year 2012
# for i in range(0, 36):
#   pyautogui.moveTo(215, 873, 0.5)
#   pyautogui.click()
#   pyautogui.moveTo(215, 813, 0.5)
#   pyautogui.click()

#   # Start Month Jan
#   pyautogui.moveTo(269, start_day_px, 0.5)
#   pyautogui.click()
#   pyautogui.moveTo(269, 668, 0.5)
#   pyautogui.click()

#   # Start Day 1
#   pyautogui.moveTo(333, 873, 0.5)
#   pyautogui.click()
#   pyautogui.moveTo(333, 535, 0.5)
#   pyautogui.click()

#   # End Year 2012
#   pyautogui.moveTo(215, 892, 0.5)
#   pyautogui.click()
#   pyautogui.moveTo(215, 832, 0.5)
#   pyautogui.click()


#   # End Month Jan
#   pyautogui.moveTo(269, 892, 0.5)
#   pyautogui.click()
#   pyautogui.moveTo(269, 687, 0.5)
#   pyautogui.click()


#   # End Day 11
#   pyautogui.moveTo(333, 892, 0.5)
#   pyautogui.click()
#   pyautogui.moveTo(333, 723, 0.5)
#   pyautogui.click()

#   # GPS and GLONASS
#   # pyautogui.moveTo(202, 913, 0.5)
#   # pyautogui.click()
#   # pyautogui.moveTo(202, 949, 0.5)
#   # pyautogui.click()

#   # Downloads
#   pyautogui.moveTo(456, 976, 0.5)
#   pyautogui.click()

#   pyautogui.moveTo(801, 308, 2)
#   pyautogui.click()

#   pyautogui.moveTo(590, 180, 0.5)
#   pyautogui.click()

#   pyautogui.moveTo(766, 280, 10)
#   pyautogui.click()
#   time.sleep(10)

#   # Start Day 12
#   pyautogui.moveTo(339, 872, 0.5)
#   pyautogui

#   pyautogui.moveTo(324, 720, 0.5)
#   pyautogui.click()

#   # End Day 22

#   pyautogui.moveTo(334, 891, 0.5)
#   pyautogui.click()

#   pyautogui.moveTo(334, 840, 0.5)
#   pyautogui.scroll(300)


#   # if i == 2:
#   #   print()
#   # elif i == 5:
    
#   # elif i == 8: 
#   # elif i == 11:
#   # elif i == 14:
#   # elif i == 17:
#   # elif i == 20:
#   # elif i == 23:
#   # elif i == 26:
#   # elif i == 29:
#   # elif i == 32:
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11920/2552214938.py in <module>
#      63   pyautogui.moveTo(766, 280, 10)
#      64   pyautogui.click()
# ---> 65   time.sleep(10)
#      66
#      67   # Start Day 12
#
# KeyboardInterrupt:

# %%
import pyautogui

pyautogui.moveTo(202, 913, 0.5)
pyautogui.click()
pyautogui.moveTo(202, 949, 0.5)
pyautogui.click()

# %%
import pyautogui
import time

start_yr_px_x = 215
start_mth_px_x = 269
start_day_px_x = 333

start_day_1 = 1
start_day_12 = 12
start_day_23 = 23

start_px_y = 873

end_yr_px_x = 215
end_mth_px_x = 269
end_day_px_x = 333

end_day_11 = 11
end_day_22 = 22
end_day_last = 0

end_px_y = 892

box_size = 17
day_box_list = 20

rapid_time_interval = 0.2
slow_time_interval = 0.5

years = [2012, 2016, 2020]

def downloadProcess():
  # Downloads
  # Click Download
  pyautogui.moveTo(456, 976, 0.2)
  pyautogui.click()

  pyautogui.sleep(3)
  # Click Download Everything
  pyautogui.moveTo(801, 308, 2)
  pyautogui.click()

  # Close the PopUp
  pyautogui.moveTo(590, 180, 0.2)
  pyautogui.click()

  pyautogui.sleep(3)

  # Close the Download Status
  pyautogui.sleep(5)
  pyautogui.moveTo(926, 993, 5)
  pyautogui.click()

  # Go Back to Download page
  pyautogui.sleep(5)
  pyautogui.moveTo(766, 280, 1)
  pyautogui.click()
  pyautogui.sleep(2)


for year in range(1, len(years) + 1):
  pyautogui.moveTo(start_yr_px_x, start_px_y, rapid_time_interval)
  pyautogui.click()

  pyautogui.moveTo(start_yr_px_x, start_px_y - 60 * year, rapid_time_interval)
  pyautogui.click()

  pyautogui.moveTo(end_yr_px_x, end_px_y, rapid_time_interval)
  pyautogui.click()

  pyautogui.moveTo(end_yr_px_x, end_px_y - 60 * year, rapid_time_interval)
  pyautogui.click()

  if year >= 2:
    # GPS and GLONASS
    pyautogui.moveTo(202, 913, 0.5)
    pyautogui.click()
    pyautogui.moveTo(202, 949, 0.5)
    pyautogui.click()

  for j in range(1, 13):
    pyautogui.moveTo(start_mth_px_x, start_px_y, rapid_time_interval)
    pyautogui.click()

    pyautogui.moveTo(start_mth_px_x, start_px_y - (12 - j + 1) * box_size, rapid_time_interval)
    pyautogui.click()

    pyautogui.moveTo(end_mth_px_x, end_px_y, rapid_time_interval)
    pyautogui.click()

    pyautogui.moveTo(end_mth_px_x, end_px_y - (12 - j + 1) * box_size, rapid_time_interval)
    pyautogui.click()
    for k in range(1, 4): 
      if k == 1:
          # Start Day 1
          pyautogui.moveTo(333, 873, 0.5)
          pyautogui.click()
          pyautogui.moveTo(333, 823, 0.5)
          pyautogui.scroll(500)
          pyautogui.moveTo(333, 535, 0.5)
          pyautogui.click()
          # End Day 11
          pyautogui.moveTo(333, 892, 0.5)
          pyautogui.click()
          pyautogui.moveTo(333, 842, 0.5)
          pyautogui.scroll(500)
          pyautogui.moveTo(333, 723, 0.5)
          pyautogui.click()

          downloadProcess()
        
      if k == 2:
        if j == 2:
          # Start Day 12
          pyautogui.moveTo(339, 870, 0.2)
          pyautogui.click()
          pyautogui.moveTo(339, 820, 0.2)
          pyautogui.scroll(500)
          pyautogui.moveTo(324, 720, 0.2)
          pyautogui.click()

          # End Day 22

          pyautogui.moveTo(334, 891, 0.3)
          pyautogui.click()

          pyautogui.moveTo(334, 840, 0.3)
          pyautogui.scroll(-500)

          pyautogui.moveTo(334, 750, 0.3)
          pyautogui.click()

          downloadProcess()

        elif j == 4 or j == 6 or j == 9 or j == 11:
          # Start Day 12
          pyautogui.moveTo(339, 870, 0.2)
          pyautogui.click()
          pyautogui.moveTo(339, 820, 0.2)
          pyautogui.scroll(500)
          pyautogui.moveTo(324, 720, 0.2)
          pyautogui.click()

          # End Day 22

          pyautogui.moveTo(334, 891, 0.3)
          pyautogui.click()

          pyautogui.moveTo(334, 840, 0.3)
          pyautogui.scroll(-500)

          pyautogui.moveTo(334, 745, 0.3)
          pyautogui.click()

          downloadProcess()
        else:
          # Start Day 12
          pyautogui.moveTo(339, 870, 0.2)
          pyautogui.click()
          pyautogui.moveTo(339, 820, 0.2)
          pyautogui.scroll(500)
          pyautogui.moveTo(324, 720, 0.2)
          pyautogui.click()

          # End Day 22

          pyautogui.moveTo(334, 891, 0.2)
          pyautogui.click()

          pyautogui.moveTo(334, 840, 0.2)
          pyautogui.scroll(-500)

          pyautogui.moveTo(334, 730, 0.2)
          pyautogui.click()

          downloadProcess()
          
      if k == 3:
        if j == 1 or j == 3 or j == 5 or j == 7 or j == 8 or j == 10 or j ==12:
          # Start Day 23
          pyautogui.moveTo(339, 870, 0.2)
          pyautogui.click()

          pyautogui.moveTo(324, 820, 0.2)
          pyautogui.scroll(-500)

          pyautogui.moveTo(334, 720, 0.2)
          pyautogui.click()
          # End Day 31

          pyautogui.moveTo(334, 891, 0.2)
          pyautogui.click()

          pyautogui.moveTo(334, 840, 0.2)
          pyautogui.scroll(-500)

          pyautogui.moveTo(334, 880, 0.2)
          pyautogui.sleep(0.2)
          pyautogui.click()

          downloadProcess()

        elif j == 4 or j == 6 or j == 9 or j == 11:
          # Start Day 23
          pyautogui.moveTo(339, 870, 0.2)
          pyautogui.click()

          pyautogui.moveTo(324, 820, 0.2)
          pyautogui.scroll(-500)

          pyautogui.moveTo(334, 740, 0.2)
          pyautogui.click()
          # End Day 30

          pyautogui.moveTo(334, 891, 0.2)
          pyautogui.click()

          pyautogui.moveTo(334, 840, 0.2)
          pyautogui.scroll(-500)

          pyautogui.moveTo(334, 870, 0.2)
          pyautogui.sleep(0.2)
          pyautogui.click()


          downloadProcess()


        else:
          # Start Day 23
          pyautogui.moveTo(339, 870, 0.2)
          pyautogui.click()

          pyautogui.moveTo(324, 820, 0.2)
          pyautogui.scroll(-500)

          pyautogui.moveTo(334, 760, 0.2)
          pyautogui.click()


          # End Day 29

          pyautogui.moveTo(334, 891, 0.2)
          pyautogui.click()

          pyautogui.moveTo(334, 840, 0.2)
          pyautogui.scroll(-500)

          pyautogui.moveTo(334, 880, 0.2)
          pyautogui.sleep(0.2)
          pyautogui.click()


          downloadProcess()
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_38652/3983955745.py in <module>
#     131           pyautogui.click()
#     132
# --> 133           downloadProcess()
#     134
#     135         elif j == 4 or j == 6 or j == 9 or j == 11:
#
# ~\AppData\Local\Temp/ipykernel_38652/3983955745.py in downloadProcess()
#      49   # Close the Download Status
#      50   pyautogui.sleep(5)
# ---> 51   pyautogui.moveTo(926, 993, 5)
#      52   pyautogui.click()
#      53
#
# ~\Anaconda3\lib\site-packages\pyautogui\__init__.py in wrapper(*args, **kwargs)
#     596     def wrapper(*args, **kwargs):
#     597         failSafeCheck()
# --> 598         returnVal = wrappedFunction(*args, **kwargs)
#     599         _handlePause(kwargs.get("_pause", True))
#     600         return returnVal
#
# ...

# %%
import pyautogui
import time

start_yr_px_x = 215
start_mth_px_x = 269
start_day_px_x = 333

start_day_1 = 1
start_day_12 = 12
start_day_23 = 23

start_px_y = 873

end_yr_px_x = 215
end_mth_px_x = 269
end_day_px_x = 333

end_day_11 = 11
end_day_22 = 22
end_day_last = 0

end_px_y = 892

box_size = 17
day_box_list = 20

rapid_time_interval = 0.2
slow_time_interval = 0.5

years = [2012, 2016, 2020]

def downloadProcess():
  # Downloads
  # Click Download
  pyautogui.moveTo(456, 976, 0.2)
  pyautogui.click()

  pyautogui.sleep(3)
  # Click Download Everything
  pyautogui.moveTo(801, 308, 2)
  pyautogui.click()

  # Close the PopUp
  pyautogui.moveTo(590, 180, 0.2)
  pyautogui.click()

  pyautogui.sleep(3)

  # Close the Download Status
  pyautogui.sleep(5)
  pyautogui.moveTo(926, 993, 5)
  pyautogui.click()

  # Go Back to Download page
  pyautogui.sleep(5)
  pyautogui.moveTo(766, 280, 1)
  pyautogui.click()
  pyautogui.sleep(2)


for year in range(2, len(years) + 1):
  pyautogui.moveTo(start_yr_px_x, start_px_y, rapid_time_interval)
  pyautogui.click()

  pyautogui.moveTo(start_yr_px_x, start_px_y - 60 * year, rapid_time_interval)
  pyautogui.click()

  pyautogui.moveTo(end_yr_px_x, end_px_y, rapid_time_interval)
  pyautogui.click()

  pyautogui.moveTo(end_yr_px_x, end_px_y - 60 * year, rapid_time_interval)
  pyautogui.click()

  if year >= 2:
    # GPS and GLONASS
    pyautogui.moveTo(202, 913, 0.5)
    pyautogui.click()
    pyautogui.moveTo(202, 949, 0.5)
    pyautogui.click()

  for j in range(1, 13):
    pyautogui.moveTo(start_mth_px_x, start_px_y, rapid_time_interval)
    pyautogui.click()

    pyautogui.moveTo(start_mth_px_x, start_px_y - (12 - j + 1) * box_size, rapid_time_interval)
    pyautogui.click()

    pyautogui.moveTo(end_mth_px_x, end_px_y, rapid_time_interval)
    pyautogui.click()

    pyautogui.moveTo(end_mth_px_x, end_px_y - (12 - j + 1) * box_size, rapid_time_interval)
    pyautogui.click()
    for k in range(1, 4): 
      if k == 1:
          # Start Day 1
          pyautogui.moveTo(333, 873, 0.5)
          pyautogui.click()
          pyautogui.moveTo(333, 823, 0.5)
          pyautogui.scroll(500)
          pyautogui.moveTo(333, 535, 0.5)
          pyautogui.click()
          # End Day 11
          pyautogui.moveTo(333, 892, 0.5)
          pyautogui.click()
          pyautogui.moveTo(333, 842, 0.5)
          pyautogui.scroll(500)
          pyautogui.moveTo(333, 723, 0.5)
          pyautogui.click()

          downloadProcess()
        
      if k == 2:
        if j == 2:
          # Start Day 12
          pyautogui.moveTo(339, 870, 0.2)
          pyautogui.click()
          pyautogui.moveTo(339, 820, 0.2)
          pyautogui.scroll(500)
          pyautogui.moveTo(324, 720, 0.2)
          pyautogui.click()

          # End Day 22

          pyautogui.moveTo(334, 891, 0.3)
          pyautogui.click()

          pyautogui.moveTo(334, 840, 0.3)
          pyautogui.scroll(-500)

          pyautogui.moveTo(334, 750, 0.3)
          pyautogui.click()

          downloadProcess()

        elif j == 4 or j == 6 or j == 9 or j == 11:
          # Start Day 12
          pyautogui.moveTo(339, 870, 0.2)
          pyautogui.click()
          pyautogui.moveTo(339, 820, 0.2)
          pyautogui.scroll(500)
          pyautogui.moveTo(324, 720, 0.2)
          pyautogui.click()

          # End Day 22

          pyautogui.moveTo(334, 891, 0.3)
          pyautogui.click()

          pyautogui.moveTo(334, 840, 0.3)
          pyautogui.scroll(-500)

          pyautogui.moveTo(334, 745, 0.3)
          pyautogui.click()

          downloadProcess()
        else:
          # Start Day 12
          pyautogui.moveTo(339, 870, 0.2)
          pyautogui.click()
          pyautogui.moveTo(339, 820, 0.2)
          pyautogui.scroll(500)
          pyautogui.moveTo(324, 720, 0.2)
          pyautogui.click()

          # End Day 22

          pyautogui.moveTo(334, 891, 0.2)
          pyautogui.click()

          pyautogui.moveTo(334, 840, 0.2)
          pyautogui.scroll(-500)

          pyautogui.moveTo(334, 730, 0.2)
          pyautogui.click()

          downloadProcess()
          
      if k == 3:
        if j == 1 or j == 3 or j == 5 or j == 7 or j == 8 or j == 10 or j ==12:
          # Start Day 23
          pyautogui.moveTo(339, 870, 0.2)
          pyautogui.click()

          pyautogui.moveTo(324, 820, 0.2)
          pyautogui.scroll(-500)

          pyautogui.moveTo(334, 720, 0.2)
          pyautogui.click()
          # End Day 31

          pyautogui.moveTo(334, 891, 0.2)
          pyautogui.click()

          pyautogui.moveTo(334, 840, 0.2)
          pyautogui.scroll(-500)

          pyautogui.moveTo(334, 880, 0.2)
          pyautogui.sleep(0.2)
          pyautogui.click()

          downloadProcess()

        elif j == 4 or j == 6 or j == 9 or j == 11:
          # Start Day 23
          pyautogui.moveTo(339, 870, 0.2)
          pyautogui.click()

          pyautogui.moveTo(324, 820, 0.2)
          pyautogui.scroll(-500)

          pyautogui.moveTo(334, 740, 0.2)
          pyautogui.click()
          # End Day 30

          pyautogui.moveTo(334, 891, 0.2)
          pyautogui.click()

          pyautogui.moveTo(334, 840, 0.2)
          pyautogui.scroll(-500)

          pyautogui.moveTo(334, 870, 0.2)
          pyautogui.sleep(0.2)
          pyautogui.click()


          downloadProcess()


        else:
          # Start Day 23
          pyautogui.moveTo(339, 870, 0.2)
          pyautogui.click()

          pyautogui.moveTo(324, 820, 0.2)
          pyautogui.scroll(-500)

          pyautogui.moveTo(334, 760, 0.2)
          pyautogui.click()


          # End Day 29

          pyautogui.moveTo(334, 891, 0.2)
          pyautogui.click()

          pyautogui.moveTo(334, 840, 0.2)
          pyautogui.scroll(-500)

          pyautogui.moveTo(334, 880, 0.2)
          pyautogui.sleep(0.2)
          pyautogui.click()


          downloadProcess()

# %%
# Start Day 12
pyautogui.moveTo(339, 870, 0.2)
pyautogui.click()

pyautogui.moveTo(324, 720, 0.2)
pyautogui.click()

# End Day 22

pyautogui.moveTo(334, 891, 0.2)
pyautogui.click()

pyautogui.moveTo(334, 840, 0.2)
pyautogui.scroll(-500)

pyautogui.moveTo(334, 720, 0.2)
pyautogui.click()

# Downloads
pyautogui.moveTo(456, 976, 0.2)
pyautogui.click()

pyautogui.sleep(3)

pyautogui.moveTo(801, 308, 2)
pyautogui.click()

pyautogui.moveTo(590, 180, 0.2)
pyautogui.click()

pyautogui.sleep(3)

pyautogui.moveTo(926, 993, 5)
pyautogui.click()

pyautogui.moveTo(766, 280, 1)
pyautogui.click()

# %%
# Start Day 23
pyautogui.moveTo(339, 870, 0.2)
pyautogui.click()

pyautogui.moveTo(324, 820, 0.2)
pyautogui.scroll(-500)

pyautogui.moveTo(334, 720, 0.2)
pyautogui.click()

# End Day 31

pyautogui.moveTo(334, 891, 0.2)
pyautogui.click()

pyautogui.moveTo(334, 840, 0.2)
pyautogui.scroll(-500)

pyautogui.moveTo(334, 880, 0.2)
pyautogui.sleep(0.2)
pyautogui.click()

# Downloads
pyautogui.moveTo(456, 976, 0.2)
pyautogui.click()

pyautogui.sleep(3)

pyautogui.moveTo(801, 308, 2)
pyautogui.click()

pyautogui.moveTo(590, 180, 0.2)
pyautogui.click()

pyautogui.sleep(3)

pyautogui.moveTo(926, 993, 5)
pyautogui.click()

pyautogui.moveTo(766, 280, 1)
pyautogui.click()

# %%
# Start Day 23
pyautogui.moveTo(339, 870, 0.2)
pyautogui.click()

pyautogui.moveTo(324, 820, 0.2)
pyautogui.scroll(-500)

pyautogui.moveTo(334, 720, 0.2)
pyautogui.click()

# End Day 31

pyautogui.moveTo(334, 891, 0.2)
pyautogui.click()

pyautogui.moveTo(334, 840, 0.2)
pyautogui.scroll(-500)

pyautogui.moveTo(334, 860, 0.2)
pyautogui.sleep(0.2)
pyautogui.click()

# # Downloads
# pyautogui.moveTo(456, 976, 0.2)
# pyautogui.click()

# pyautogui.sleep(3)

# pyautogui.moveTo(801, 308, 2)
# pyautogui.click()

# pyautogui.moveTo(590, 180, 0.2)
# pyautogui.click()

# pyautogui.sleep(3)

# pyautogui.moveTo(926, 993, 5)
# pyautogui.click()

# pyautogui.moveTo(766, 280, 1)
# pyautogui.click()

# %%
# Start Day 23
pyautogui.moveTo(339, 870, 0.2)
pyautogui.click()

pyautogui.moveTo(324, 820, 0.2)
pyautogui.scroll(-500)

pyautogui.moveTo(334, 720, 0.2)
pyautogui.click()

# End Day 31

pyautogui.moveTo(334, 891, 0.2)
pyautogui.click()

pyautogui.moveTo(334, 840, 0.2)
pyautogui.scroll(-500)

pyautogui.moveTo(334, 845, 0.2)
pyautogui.sleep(0.2)
pyautogui.click()

# # Downloads
# pyautogui.moveTo(456, 976, 0.2)
# pyautogui.click()

# pyautogui.sleep(3)

# pyautogui.moveTo(801, 308, 2)
# pyautogui.click()

# pyautogui.moveTo(590, 180, 0.2)
# pyautogui.click()

# pyautogui.sleep(3)

# pyautogui.moveTo(926, 993, 5)
# pyautogui.click()

# pyautogui.moveTo(766, 280, 1)
# pyautogui.click()
